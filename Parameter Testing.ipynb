# %%
max(naive.history['val_acc'])
# Out:
# 0.9765

# %%
min(naive.history['val_loss'])
# Out:
# 0.09141943417340517

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,), kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('relu'),
            Dropout(0.5),
            Dense(50, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('relu'),
            Dropout(0.5),
            Dense(10, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tuned = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 2s 37us/step - loss: 1.7893 - acc: 0.6593 - val_loss: 1.0755 - val_acc: 0.9126
# Epoch 2/100
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.8845 - acc: 0.8122 - val_loss: 0.6174 - val_acc: 0.9292
# Epoch 3/100
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.7443 - acc: 0.8346 - val_loss: 0.4503 - val_acc: 0.9298
# Epoch 4/100
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.6995 - acc: 0.8407 - val_loss: 0.4123 - val_acc: 0.9331
# Epoch 5/100
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.6702 - acc: 0.8482 - val_loss: 0.3796 - val_acc: 0.9380
# Epoch 6/100
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.6537 - acc: 0.8524 - val_loss: 0.3712 - val_acc: 0.9341
# Epoch 7/100
# ...

# %%
plot_history(tuned, 'Tuned Model');

# %%
min(tuned.history['val_loss'])
# Out:
# 0.31505638246536255

# %%
max(tuned.history['val_acc'])
# Out:
# 0.9475

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,), kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(50, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(10, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
            BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tuned2 = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 1.1245 - acc: 0.8974 - val_loss: 0.8418 - val_acc: 0.9388
# Epoch 2/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.3717 - acc: 0.9528 - val_loss: 0.3404 - val_acc: 0.9624
# Epoch 3/100
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.2721 - acc: 0.9598 - val_loss: 0.2569 - val_acc: 0.9600
# Epoch 4/100
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.2381 - acc: 0.9631 - val_loss: 0.2570 - val_acc: 0.9562
# Epoch 5/100
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.2225 - acc: 0.9644 - val_loss: 0.2132 - val_acc: 0.9691
# Epoch 6/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2103 - acc: 0.9654 - val_loss: 0.1981 - val_acc: 0.9694
# Epoch 7/100
# ...

# %%
plot_history(tuned2, 'Without Dropout Model');

# %%
max(naive.history['val_acc'])
# Out:
# 0.9765

# %%
max(tuned2.history['val_acc'])
# Out:
# 0.9713

# %%
min(tuned2.history['val_loss'])
# Out:
# 0.17876536967754364

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,), kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(50, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(10, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
            BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tuned3 = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.6913 - acc: 0.8910 - val_loss: 0.4442 - val_acc: 0.9509
# Epoch 2/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.3439 - acc: 0.9555 - val_loss: 0.2916 - val_acc: 0.9626
# Epoch 3/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2474 - acc: 0.9651 - val_loss: 0.2304 - val_acc: 0.9650
# Epoch 4/100
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.1970 - acc: 0.9707 - val_loss: 0.1968 - val_acc: 0.9688
# Epoch 5/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1690 - acc: 0.9734 - val_loss: 0.1643 - val_acc: 0.9726
# Epoch 6/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1484 - acc: 0.9761 - val_loss: 0.1690 - val_acc: 0.9675
# Epoch 7/100
# ...

# %%
plot_history(tuned3, 'Without Dropout Model');

# %%
max(tuned3.history['val_acc'])
# Out:
# 0.9786

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,), kernel_regularizer=l2(0.005), bias_regularizer=l2(0.005)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(50, kernel_regularizer=l2(0.005), bias_regularizer=l2(0.005)),
            BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(10, kernel_regularizer=l2(0.005), bias_regularizer=l2(0.005)),
            BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tuned4 = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.9446 - acc: 0.8946 - val_loss: 0.6996 - val_acc: 0.9529
# Epoch 2/100
# 60000/60000 [==============================] - 1s 25us/step - loss: 0.3793 - acc: 0.9564 - val_loss: 0.3982 - val_acc: 0.9535
# Epoch 3/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.2599 - acc: 0.9631 - val_loss: 0.2484 - val_acc: 0.9678
# Epoch 4/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.2180 - acc: 0.9669 - val_loss: 0.2117 - val_acc: 0.9673
# Epoch 5/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1974 - acc: 0.9678 - val_loss: 0.2007 - val_acc: 0.9666
# Epoch 6/100
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1819 - acc: 0.9696 - val_loss: 0.1957 - val_acc: 0.9646
# Epoch 7/100
# ...

# %%
plot_history(tuned4, 'Without Dropout Model');

# %%
max(tuned4.history['val_acc'])
# Out:
# 0.9747

# %%
min(tuned4.history['val_loss'])
# Out:
# 0.15083333315849304

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,), kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
#             BatchNormalization(),
            Activation('relu'),
#             Dropout(0.5),
            Dense(50, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
#             BatchNormalization(),
            Activation('relu'),
            Dropout(0.1),
            Dense(10, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)),
#             BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

tuned3 = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.6131 - acc: 0.8619 - val_loss: 0.3588 - val_acc: 0.9349
# Epoch 2/100
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.3617 - acc: 0.9351 - val_loss: 0.3104 - val_acc: 0.9470
# Epoch 3/100
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.3148 - acc: 0.9480 - val_loss: 0.2804 - val_acc: 0.9566
# Epoch 4/100
# 60000/60000 [==============================] - 2s 26us/step - loss: 0.2894 - acc: 0.9551 - val_loss: 0.2573 - val_acc: 0.9622
# Epoch 5/100
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.2710 - acc: 0.9602 - val_loss: 0.2489 - val_acc: 0.9650
# Epoch 6/100
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.2599 - acc: 0.9628 - val_loss: 0.2456 - val_acc: 0.9653
# Epoch 7/100
# ...

# %%
plot_history(tuned3, 'Without Dropout Model');
print(max(tuned3.history['val_acc']))
min(tuned3.history['val_loss'])
# Out:
# 0.9774
# 0.20691678700447083

# %%
from keras.layers import BatchNormalization, Dropout
from keras.regularizers import l1, l2

model = Sequential([
            Dense(50, input_shape=(784,)),
            BatchNormalization(),
            Activation('relu'),
            Dropout(0.1),
            Dense(50),
            BatchNormalization(),
            Activation('relu'),
            Dropout(0.1),
            Dense(10),
            BatchNormalization(),
            Activation('softmax')
        ])

model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

dropout = model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.6753 - acc: 0.8645 - val_loss: 0.3349 - val_acc: 0.9447
# Epoch 2/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.3478 - acc: 0.9307 - val_loss: 0.2163 - val_acc: 0.9590
# Epoch 3/100
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.2569 - acc: 0.9447 - val_loss: 0.1665 - val_acc: 0.9646
# Epoch 4/100
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.2055 - acc: 0.9520 - val_loss: 0.1369 - val_acc: 0.9675
# Epoch 5/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1743 - acc: 0.9575 - val_loss: 0.1206 - val_acc: 0.9686
# Epoch 6/100
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1542 - acc: 0.9609 - val_loss: 0.1085 - val_acc: 0.9723
# Epoch 7/100
# ...

# %%
plot_history(dropout, 'Without Dropout Model');
print(max(dropout.history['val_acc']))
print(min(dropout.history['val_loss']))
# Out:
# 0.9786
# 0.07161755806636065
